# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import lightkurve as lk
# Out:
# c:\AstrolenAI_envo\astro_env\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
from src.preprocessing.preprocess_pipeline import preprocess

# %%
search_result = lk.search_lightcurve(
    "Kepler-10",
    mission="Kepler"
)

# %%
lcs = search_result.download_all()

# %%
lc = lcs.stitch()

# %%
lc = lc.remove_nans()

# %%
print(type(lc))
print(len(lc.time))
# Out:
# <class 'lightkurve.lightcurve.KeplerLightCurve'>
# 1513160

# %%
processed_lc = preprocess(lc)

processed_lc.plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
processed_lc = preprocess(lc)

print(
    "Raw Std:",
    lc.flux.std()
)

print(
    "Processed Std:",
    processed_lc.flux.std()
)
# Out:
# Raw Std: 0.00037770448855466713
# Processed Std: 0.00020309737572236667
